# %% [markdown]
# # Aufgabe 2 Test Runner
#
# This notebook is intended for Binder. Run the cells below to execute the two required unit tests and inspect the generated log files.

# %%
# !python -m unittest discover -s tests -v

# %%
from pathlib import Path

for log_name in ['fit.log', 'predict.log']:
    log_path = Path('logs') / log_name
    print(f'===== {log_name} =====')
    if log_path.exists():
        print(log_path.read_text())
    else:
        print('Log file not created yet.')
